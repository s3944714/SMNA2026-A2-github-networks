# %%
import os

# Always run from project root regardless of where the notebook lives
os.chdir(os.path.dirname(os.path.abspath("__file__")) + "/..")

# Confirm
print(f"Working directory: {os.getcwd()}")
print(f"data/raw exists: {os.path.exists('data/raw')}")
# Out:
# Working directory: /Users/rob/Desktop/2026/social/SMNA2026-A2-github-networks
# data/raw exists: True

# %% [markdown]
# # COSC 2671 — Assignment 2
# ## Notebook 3: Network Analysis
#
# Builds and analyses directed weighted contributor networks.
# - Nodes: GitHub users
# - Edges: A → B when A comments on an issue opened by B (weighted by count)
#
# Analyses:
# 1. Basic network statistics
# 2. PageRank + betweenness + composite centrality
# 3. Louvain community detection
# 4. k-Core decomposition (HD extension)
# 5. Cross-repository comparison
# 6. Visualisation (pyvis)
